# %%
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt

#test0,test1-->pinn
#nntest0,nnteest1-->FNN

test0=np.loadtxt('0/test.dat', unpack = True)
test1=np.loadtxt('1/test.dat', unpack = True)
test0 = pd.DataFrame(test0.T)
test1 = pd.DataFrame(test1.T)


train0=np.loadtxt('0/train.dat', unpack = True)
train1=np.loadtxt('1/train.dat', unpack = True)
train0 = pd.DataFrame(train0.T)
train1 = pd.DataFrame(train1.T)
print(len(train1))

# plt.plot(test0[0],test0[1])

# plt.plot(test0[0],test0[2],label=chr(955)+'=0',c='black')

plt.plot(test0[0],test0[1],c='black',label=chr(955)+'=0')
plt.scatter(train0[0],train0[1],c='green',s=20)


# plt.plot(test1[0],test1[2],label=chr(955)+'=1')

plt.plot(test1[0],test1[1],c='blue',label=chr(955)+'=1')
plt.scatter(train1[0],train1[1],c='green',label='Training points',s=20)

# plt.fill_between(test0[0],test0[1],test1[1], alpha=0.1)
# plt.text(140, 150, r'$A_{thi}^{\dot {\gamma _{s}} \to \dot {\gamma _{e}}}$ ')

# plt.text(103, 100, r'$Thi_{\dot{\gamma }}$',color='red')

# plt.vlines(x=100, color='r', ymin = 70, ymax = 190,linestyle='-')
# plt.vlines(x=100, color='r', ymin = 0, ymax = 70,linestyle='--')


plt.legend()
plt.xlabel('$\dot{\gamma }$ ',fontproperties = 'Times New Roman', size = 14)
plt.ylabel(r'$\mathbf{\tau }$ ',fontproperties = 'Times New Roman', size = 14)
plt.xlim(0,200)
plt.ylim(0,300)

plt.savefig('lineplot.png',dpi=600,bbox_inches = 'tight')
# Out:
# 45

# %%
plt.plot(test0[0],test0[1]/test0[0],c='black',label=chr(955)+'=0')
# plt.scatter(train0[0],train0[1]/test0[0],c='green',s=20)


# plt.plot(test1[0],test1[2],label=chr(955)+'=1')

plt.plot(test1[0],test1[1]/test1[0],c='blue',label=chr(955)+'=1')
# plt.scatter(train1[0],train1[1],c='green',label='Training points',s=20)

plt.fill_between(test0[0],test0[1]/test0[0],test1[1]/test1[0], alpha=0.1)
plt.text(50, 1.2, r'$A_{thi}^{\dot {\gamma _{s}} \to \dot {\gamma _{e}}}$ ')

plt.text(110, 1.1, r'$Thi_{\dot{\gamma }}$',color='red')

plt.vlines(x=100, color='r', ymin = 0.8, ymax = 1.8,linestyle='-')
plt.vlines(x=100, color='r', ymin = 0, ymax = 0.8,linestyle='--')


plt.legend()
plt.xlabel('$\dot{\gamma }$ ',fontproperties = 'Times New Roman', size = 14)
plt.ylabel(r'$\mathbf{\eta  }$ ',fontproperties = 'Times New Roman', size = 14)
# plt.xlim(0,200)
# plt.ylim(0,300)
plt.yscale('log')

plt.savefig('eta-gamma_dot.png',dpi=600,bbox_inches = 'tight')

# %% [markdown]
# # PINN

# %%
nntest0=pd.read_csv('0/nntest.csv')
nntest1=pd.read_csv('1/nntest.csv')
plt.plot(test0[0],test0[2],'-.b',label='RheologyNet',c='black')
plt.plot(test1[0],test1[2],'-.b',c='black')
plt.plot(test0[0],test0[1],'--r')
plt.plot(test1[0],test1[1],'--r',label="Exact solution")
# plt.fill_between(test0[0],test0[2],test1[2], alpha=0.1)
plt.xlabel('$\dot{\gamma }$ ',fontproperties = 'Times New Roman', size = 14)
plt.ylabel(r'$\mathbf{\tau }$ ',fontproperties = 'Times New Roman', size = 14)
plt.legend()
plt.xlim(0,200)
plt.ylim(0,300)
plt.savefig('lineplot-pinn.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.b" (-> color='b'). The keyword argument will take precedence.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.b" (-> color='b'). The keyword argument will take precedence.
#   after removing the cwd from sys.path.

# %%
nntest0=pd.read_csv('0/nntest.csv')
nntest1=pd.read_csv('1/nntest.csv')
plt.plot(test0[0],test0[2]/test0[0],'-.b',label='RheologyNet',c='black')
plt.plot(test1[0],test1[2]/test1[0],'-.b',c='black')
plt.plot(test0[0],test0[1]/test0[0],'--r')
plt.plot(test1[0],test1[1]/test1[0],'--r',label="Exact solution")
plt.fill_between(test0[0],test0[2]/test0[0],test1[2]/test1[0], alpha=0.1,label='Thixotropy Area')
plt.xlabel('$\dot{\gamma }$ ',fontproperties = 'Times New Roman', size = 14)
plt.ylabel(r'$\mathbf{\eta  }$ ',fontproperties = 'Times New Roman', size = 14)
plt.legend()
# plt.xlim(0,200)
# plt.ylim(0,300)
plt.yscale('log')
plt.savefig('eta-pinn.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.b" (-> color='b'). The keyword argument will take precedence.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.b" (-> color='b'). The keyword argument will take precedence.
#   after removing the cwd from sys.path.

# %%
plt.plot(nntest0['0'],nntest0['1'],'-.b',label='FNN',alpha=0.5)
plt.plot(nntest1['0'],nntest1['1'],'-.b',alpha=0.5)
# plt.fill_between(nntest0['0'],nntest0['1'],nntest1['1'], alpha=0.1)
plt.plot(test0[0],test0[1],'--r')
plt.plot(test1[0],test1[1],'--r',label="Exact solution")
plt.xlabel('$\dot{\gamma }$ ',fontproperties = 'Times New Roman', size = 14)
plt.ylabel(r'$\mathbf{\tau }$ ',fontproperties = 'Times New Roman', size = 14)
plt.legend()
plt.xlim(0,200)
plt.ylim(0,300)
plt.savefig('lineplot-fnn.png',dpi=600,bbox_inches = 'tight')

# %%
plt.plot(nntest0['0'],nntest0['1']/nntest0['0'],'-.b',label='FNN',alpha=0.5)
plt.plot(nntest1['0'],nntest1['1']/nntest1['0'],'-.b',alpha=0.5)
plt.plot(test0[0],test0[1]/test0[0],'--r')
plt.plot(test1[0],test1[1]/test1[0],'--r',label="Exact solution")
plt.fill_between(nntest0['0'],nntest0['1']/nntest0['0'],nntest1['1']/nntest1['0'], alpha=0.1,label='Thixotropy Area')

plt.xlabel('$\dot{\gamma }$ ',fontproperties = 'Times New Roman', size = 14)
plt.ylabel(r'$\mathbf{\eta  }$ ',fontproperties = 'Times New Roman', size = 14)
plt.legend()
# plt.xlim(0,200)
# plt.ylim(0,300)
plt.yscale('log')
plt.savefig('eta-fnn.png',dpi=600,bbox_inches = 'tight')

# %%
plt.plot(nntest0['0'],nntest0['1'],'-.b',label='NN Prediction',alpha=0.5)
plt.plot(nntest1['0'],nntest1['1'],'-.b',alpha=0.5)
# plt.fill_between(nntest0['0'],nntest0['1'],nntest1['1'], alpha=0.1)
# plt.fill_between(nntest0['0'],nntest0['1'],test0[1], alpha=0.1)
# plt.fill_between(nntest0['0'],nntest1['1'],test1[1],where=(nntest1['1']>test1[1]),color='green', alpha=0.1)

plt.xlabel('$\dot{\gamma }$ ',fontproperties = 'Times New Roman', size = 14)
plt.ylabel(r'$\mathbf{\tau }$ ',fontproperties = 'Times New Roman', size = 14)

plt.plot(test0[0],test0[1],'--r')
plt.plot(test1[0],test1[1],'--r',label="Exact solution")
plt.scatter(train1[0],train1[1],c='green',label='Training points',s=20)
plt.scatter(train0[0],train0[1],c='green',s=20)
plt.legend()
plt.xlim(0,50)
plt.ylim(0,80)
plt.savefig('lineplot-fnn-part.png',dpi=600,bbox_inches = 'tight')

# %%
plt.plot(nntest0['0'],nntest0['1']/nntest0['0'],'-.b',label='FNN',alpha=0.5)
plt.plot(nntest1['0'],nntest1['1']/nntest1['0'],'-.b',alpha=0.5)
plt.plot(test0[0],test0[1]/test0[0],'--r')
plt.plot(test1[0],test1[1]/test1[0],'--r',label="Exact solution")
plt.fill_between(nntest0['0'],nntest0['1']/nntest0['0'],nntest1['1']/nntest1['0'], alpha=0.1,label='Thixotropy Area')
# plt.fill_between(nntest0['0'],nntest0['1'],nntest1['1'], alpha=0.1)
plt.scatter(train1[0],train1[1]/train1[0],c='green',label='Training points',s=20)
plt.scatter(train0[0],train0[1]/train0[0],c='green',s=20)

plt.xlabel('$\dot{\gamma }$ ',fontproperties = 'Times New Roman', size = 14)
plt.ylabel(r'$\mathbf{\eta  }$ ',fontproperties = 'Times New Roman', size = 14)
plt.legend()
plt.xlim(0,30)
# plt.ylim(0,300)
plt.yscale('log')
plt.savefig('eta-fnn-part.png',dpi=600,bbox_inches = 'tight')

# %%
nntest0=pd.read_csv('0/nntest.csv')
plt.plot(nntest0['0'],nntest0['1'],label='NN Prediction')
plt.plot(test0[0],test0[2],'-.b',label='PINN Prediction',c='black')
plt.plot(test0[0],test0[1],'--r',alpha=0.5,label="Exact solution")
# plt.scatter(train0[0],train0[1],c='green',alpha=0.3,s=20,label='Train points')
plt.legend()
plt.xlabel('Shear Rate')
plt.ylabel('Shear Stress')
plt.xscale('log')
plt.yscale('log')
plt.savefig('comparison0.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.b" (-> color='b'). The keyword argument will take precedence.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
nntest1=pd.read_csv('1/nntest.csv')
plt.plot(nntest1['0'],nntest1['1'],label='NN Prediction')
plt.plot(test1[0],test1[2],'-.b',label='PINN Prediction',c='black')
plt.plot(test1[0],test1[1],'--r',alpha=0.5,label="Exact solution")
# plt.scatter(train1[0],train1[1],c='green',alpha=0.3,s=20,label='Train points')
plt.legend()
plt.xlabel('Shear Rate')
plt.ylabel('Shear Stress')
# plt.xscale('log')
# plt.yscale('log')
plt.savefig('comparison1.png',dpi=600,bbox_inches = 'tight')
# Out:
# /Users/zhangtianjie/opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-.b" (-> color='b'). The keyword argument will take precedence.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
(test1[1]-test0[1]).sum()
# Out:
# 107360.86790561676

# %%
(test1[2]-test0[2]).sum()
# Out:
# 107335.10050201416

# %%
(nntest1['1']-nntest0['1']).sum()
# Out:
# 106234.36111600001

# %%
print(abs((test1[2]-test0[2]).sum()-(test1[1]-test0[1]).sum())/(test1[1]-test0[1]).sum())
print(abs((nntest1['1']-nntest0['1']).sum()-(test1[1]-test0[1]).sum())/(test1[1]-test0[1]).sum())
# Out:
# 0.0002400074077759205
# 0.010492713142064779

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(test1[1],test1[2]))
print(mean_squared_error(test0[1],test0[2]))
print(mean_squared_error(test1[1],nntest1['1']))
print(mean_squared_error(test0[1],nntest0['1']))
# Out:
# 0.0694685435544734
# 0.00124458429711558
# 1.5709104780855152
# 0.03591662488228931

# %%
print('solution of whole area',(test1[1]-test0[1]).sum())
print('solution variance of whole area',(test1[1]-test0[1]).var())
print('PINN of whole area',(test1[2]-test0[2]).sum())
print('PINN variance of whole area',(test1[2]-test0[2]).var())
print('FNN of whole area',(nntest1['1']-nntest0['1']).sum())
print('FNN variance of whole area',(nntest1['1']-nntest0['1']).var())
print('FNN relative error of area',
      abs((nntest1['1']-nntest0['1']).sum()-(test1[1]-test0[1]).sum())/(test1[1]-test0[1]).sum())
print('PINN relative error of area',
      abs((test1[2]-test0[2]).sum()-(test1[1]-test0[1]).sum())/(test1[1]-test0[1]).sum())
print('FNN relative error of variance',
      abs((nntest1['1']-nntest0['1']).var()-(test1[1]-test0[1]).var())/(test1[1]-test0[1]).var())
print('PINN relative error of variance',
      abs((test1[2]-test0[2]).var()-(test1[1]-test0[1]).var())/(test1[1]-test0[1]).var())
from sklearn.metrics import mean_squared_error
print('PINN lambda=1:',mean_squared_error(test1[1],test1[2]))
print('PINN lambda=0:',mean_squared_error(test0[1],test0[2]))
print('FNN lambda=1:',mean_squared_error(test1[1],nntest1['1']))
print('FNN lambda=0:',mean_squared_error(test0[1],nntest0['1']))

print('PINN lambda=1 1/3:',mean_squared_error(test1[1][0:333],test1[2][0:333]))
print('PINN lambda=0 1/3:',mean_squared_error(test0[1][0:333],test0[2][0:333]))
print('FNN lambda=1 1/3:',mean_squared_error(test1[1][0:333],nntest1['1'][0:333]))
print('FNN lambda=0 1/3:',mean_squared_error(test0[1][0:333],nntest0['1'][0:333]))

print('PINN lambda=1 2/3:',mean_squared_error(test1[1][333:666],test1[2][333:666]))
print('PINN lambda=0 2/3:',mean_squared_error(test0[1][333:666],test0[2][333:666]))
print('FNN lambda=1 2/3:',mean_squared_error(test1[1][333:666],nntest1['1'][333:666]))
print('FNN lambda=0 2/3:',mean_squared_error(test0[1][333:666],nntest0['1'][333:666]))

print('PINN lambda=1 3/3:',mean_squared_error(test1[1][666:1000],test1[2][666:1000]))
print('PINN lambda=0 3/3:',mean_squared_error(test0[1][666:1000],test0[2][666:1000]))
print('FNN lambda=1 3/3:',mean_squared_error(test1[1][666:1000],nntest1['1'][666:1000]))
print('FNN lambda=0 3/3:',mean_squared_error(test0[1][666:1000],nntest0['1'][666:1000]))
# Out:
# solution of whole area 107360.86790561676
# solution variance of whole area 2395.4998457594143
# PINN of whole area 107335.10050201416
# PINN variance of whole area 2402.1279184252267
# FNN of whole area 106234.36111600001
# FNN variance of whole area 2411.110310233018
# FNN relative error of area 0.010492713142064779
# PINN relative error of area 0.0002400074077759205
# FNN relative error of variance 0.006516579202139329
# PINN relative error of variance 0.002766885031341417
# PINN lambda=1: 0.0694685435544734
# PINN lambda=0: 0.00124458429711558
# FNN lambda=1: 1.5709104780855152
# FNN lambda=0: 0.03591662488228931
# PINN lambda=1 1/3: 0.10759222539025348
# PINN lambda=0 1/3: 0.0027900334180804413
# FNN lambda=1 1/3: 2.326501726301284
# FNN lambda=0 1/3: 0.08751494058135283
# PINN lambda=1 2/3: 0.00022655461674315615
# PINN lambda=0 2/3: 4.1989215036823384e-05
# FNN lambda=1 2/3: 1.201832973638212
# FNN lambda=0 2/3: 0.006177608174001581
# PINN lambda=1 3/3: 0.10049368207228598
# ...
